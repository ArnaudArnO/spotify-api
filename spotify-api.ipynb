# %%
import requests
import pandas as pd
import json
import webbrowser
import function_spotify as fs
import config
import importlib

# %%
user_id_arnaud = config.user_id_arnaud
client_id = config.CLIENT_ID
client_secret = config.CLIENT_SECRET
redirect_uri = config.REDIRECT_URI
base_url = config.BASE_URL

# %%
importlib.reload(fs)
fs.get_code_with_scope(client_id)

# %%
code = 'AQCyn2QNV078mP4SvRH_pwWJM6BcjcZyIxVLV6mS_JjZ9Ntux1w7pU6S0NUWXl71g4YN-OZjpKnEtK0-YVXuDmLk2LUeIKYxAJscTRlJM-nU9MnIzEn30G-0ll-H49wzfB1AdDnKIZ4eMP6CA1iqX8KSUDtVBLAvw_rwCfZpvcji7MKY1QQuPMLYXLkPn4B89PM-idL9bAqbcnqyAILi9F2JnqPUT1za7tLtclwblP4P4vuS-SMuPACB-6wJ49ZYfJJS5zRy0uZmZyh4lIp8x_wFesQW1-yQ3TRvV3s'
importlib.reload(fs)
headers = fs.create_header(code)

# %%
print(headers)
# Out:
# {'Authorization': 'Bearer BQCkAYdOBuQnFvUT6gDzKr21iIfT2y16-S8ndMRhKK4bib2zyYbdIvXPv54HThoOB8iP4R7CwgKQzs3UxwxfKbTtMn3PipQ_9hj9Xdebt0xv6oAeHhT-ivtC-8IkQqfdN8JDdcf8BPYel3872Mimm8Zw6xg6LPzl44tlfGQb4r35CEqvoVfcTPqOTnqAkqdcgNGIghWAEaYHjxrW1Xa4DBqKVLpzp4k9s3_JOn-UhIkH2WBVun7wlbfhNo0iAnVMG7IPYAkxf7QQWg'}

# %%
importlib.reload(fs)
fs.get_playlist_for_user(headers, user_id_arnaud)
# Out:
# Hiver 2024  ---  spotify:playlist:6Dqiu3b7Dlb1wzcClPVfgm
# Remember  ---  spotify:playlist:6P7qCiaC751UghkB5PPG62
# Old remenber  ---  spotify:playlist:2LTYKSeGUOc4SQRQP2uyg8
# From armand  ---  spotify:playlist:3woiStImKrFVLALSKnq9Se
# old song  ---  spotify:playlist:0xRSRs9gHTkBLB1Z2eUz9c
# Tristesse  ---  spotify:playlist:16XjndRzuXqxfsdPwcID9J
# rap fr  ---  spotify:playlist:3LsGw4xFs0DC6uPxFKG8rc
# ETE_2024  ---  spotify:playlist:73sVagBBhgixgzYuD9xVaY
# Vincent + Arnaud  ---  spotify:playlist:37i9dQZF1EJADtowjvOQ36
# Lo-Fi House  ---  spotify:playlist:37i9dQZF1DXbXD9pMSZomS
# Beginning 2024  ---  spotify:playlist:7xOi9czXvRnngB4Jz3huvN
# Dessin animé  ---  spotify:playlist:26D5XIdlWerTSd1xpaTMgZ
# casse toi samoton  ---  spotify:playlist:37i9dQZF1EJGBFSqrdcqQL
# My recommendation playlist  ---  spotify:playlist:6SJuBOifJpc1UCmBA3vHki
# My recommendation playlist  ---  spotify:playlist:5qwSZnALZzd9o6zXcqyVxQ
# Hiver  ---  spotify:playlist:7aENUcxCa6BGusfMzNbEYR
# ...

# %%
## Recupere les info d'une playlist
playlist_id = '1NZiX19nibdIPqHPKq5Cvr'
importlib.reload(fs)
fs.print_track_for_playlist(headers, playlist_id)
# Out:
# Vois sur ton chemin - Techno Mix --- spotify:track:31nfdEooLEq7dn3UMcIeB5
# Il suffirait de presque rien --- spotify:track:39K2ov9q6HPFhBjTx5YSQ0
# Minefields --- spotify:track:1OU4E4HiVjdak0mL4blVWT
# Goodbye --- spotify:track:0e8CxZ3UlZIIV3ZRkzHN34
# When I Grow Up --- spotify:track:5rLyYxZNzca00ENADO9m54
# Hey Ya! --- spotify:track:2PpruBYCo4H7WOBJ7Q2EwM
# Take Me Home, Country Roads --- spotify:track:1QbOvACeYanja5pbnJbAmk
# Life's for the Living --- spotify:track:5GS5ZEQoypLdKfulhzZ1Uh
# Exploration Of Space --- spotify:track:3SBvSdQhQiC0Z07A9Be02F
# Elle ne t'aime pas --- spotify:track:6QEvbmv2euCQxX54gjlarO
# OH MADELEINE --- spotify:track:6kWZawOZf9vy3xeeXTGQIX
# Nan Slapper --- spotify:track:3119sJaLXEShGT5e8frnMj
# Jump Dance Move Bounce --- spotify:track:4BSJd6jkmroYkGKIrrstUa
# UFO (Crazy Frog) --- spotify:track:7pDvL8Ti5tqWsDzUhVUxkz
# Lost In Paradise - Edit --- spotify:track:10WobHNbDyqUBpSc2tfw8m
# Insomnia - Techno --- spotify:track:4VUqbK6N3TywXJhtiRJH2q
# ...

# %%
## My usefull playlist 2024: 
playlist2024 = '1NZiX19nibdIPqHPKq5Cvr'
playlist2024_hiver = '6Dqiu3b7Dlb1wzcClPVfgm'
playlist2024_begging = '7xOi9czXvRnngB4Jz3huvN'

# %%
importlib.reload(fs)
fs.merge_playlist(headers, playlist2024 ,playlist2024_hiver)
# Out:
# 201
# {'snapshot_id': 'AAAAD31+2QKdBhNgpb9YeoIAAO5zpYqZ'}

# %%
importlib.reload(fs)
fs.find_duplicate_track(headers, playlist2024)
# Out:
# Aucun doublon trouvé dans la playlist.
# []

# %%
importlib.reload(fs)
fs.delete_duplicate_track(headers, playlist2024)
# Out:
# Aucun doublon trouvé dans la playlist.
# Status Code Delete : 400
# Status Code Add : 400

# %%
importlib.reload(fs)
not_in_playlist = fs.can_i_delete_playlist(headers, playlist2024, playlist2024_begging)
# Out:
# Toutes les chansons de la playlist Beginning 2024 sont déjà dans la playlist 2024. Vous pouvez supprimer la playlist sans perdre de musique.
